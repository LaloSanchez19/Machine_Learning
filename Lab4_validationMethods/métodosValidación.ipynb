# %% [markdown]
# # Ejercicio de Lab 4. Metodos de validacion

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut

# %% [markdown]
# # Leemos los dos dataset

# %%
diabetes = pd.read_csv('diabetes_prediction_dataset.csv')
diabetes = diabetes.drop_duplicates() # Eliminamos los datos dublicados
diabetes.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
creditCard = pd.read_csv('CreditCard_Approvals.csv')
creditCard.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# 1       ByBirth       43     560         1
# 2       ByBirth      280     824         1
# 3       ByBirth      100       3         1
# 4  ByOtherMeans      120       0         1

# %% [markdown]
# ## Creamos funciones para cada metodo de validacion

# %% [markdown]
# ### Holdout.

# %%
def holdout_validation(X,y,r):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=r, random_state=42)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### K-Fold Cross-Validation.

# %%
def k_fold_cross_validation(X, y, K):
    kf = KFold(n_splits=K, shuffle=True, random_state=42)
    
    folds = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        folds.append((X_train, X_test, y_train, y_test))
    
    return folds

# %% [markdown]
# ### Leave-One-Out.

# %%
def leave_one_out_validation(X, y):
    loo = LeaveOneOut()
    leaveVali = []
    
    for train_index, test_index in loo.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        leaveVali.append((X_train, X_test, y_train, y_test))

    return leaveVali

# %% [markdown]
# ### Funcion para comprobar que los conjuntos de entrenamiento y prueba son disjuntos

# %%
def check_datasets(X_train, X_test):
    intersection = pd.merge(X_train, X_test, how='inner')
    
    if intersection.empty:
        print("Los conjuntos de entrenamiento y prueba son disjuntos.")
    else:
        print("Los conjuntos de entrenamiento y prueba NO son disjuntos.")
        print(intersection)

# %% [markdown]
# ## Prueba de las validaciones con cada metodo

# %%
# Data de la diabetes
X = diabetes[['gender','age','hypertension','heart_disease','smoking_history','bmi','HbA1c_level','blood_glucose_level']]
y = diabetes['diabetes']

r = float(input("Ingrese el valor de r: "))
X_train, X_test, y_train, y_test = holdout_validation(X, y, r)

check_datasets(X_train,X_test)
# Out:
# Ingrese el valor de r:  0.3
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0   Female  80.0             0              0           never  27.32
# 1   Female  28.0             0              0         No Info  27.32
# 2   Female  48.0             0              0         current  27.32
# 3   Female  56.0             0              0           never  27.32
# 4   Female  60.0             0              0         No Info  27.32
# 5   Female  68.0             0              0         No Info  27.32
# 6   Female  47.0             0              0         No Info  27.32
# 7     Male  55.0             0              0           never  27.32
# 8     Male  80.0             0              0         No Info  27.32
# 9   Female  68.0             0              0           never  27.32
# 10  Female  37.0             0              0         No Info  27.32
# 11  Female  79.0             0              0         No Info  27.32
# 12    Male  51.0             0              0           never  27.32
# 13    Male  64.0             0              0         No Info  27.32
# 14  Female  80.0             0              0         No Info  27.32
# 15    Male  62.0             0              0           never  27.32
# 16  Female  80.0             0              0         No Info  27.32
# 17  Female  80.0             1              0         No Info  27.32
# 18  Female  80.0             0              0           never  27.32
# 19    Male  73.0             0              0         No Info  27.32
# 20    Male  53.0             0              0         No Info  27.32
# 21  Female  53.0             0              0         No Info  27.32
# 22    Male  64.0             0              0         No Info  27.32
# 23    Male  55.0             0              0         No Info  27.32
# 24  Female  45.0             0              0         No Info  27.32
# 25  Female  80.0             0              0           never  27.32
# 26    Male  68.0             0              0          former  27.32
# 27  Female  57.0             0              0         No Info  27.32
# 28  Female  58.0             0              0           never  27.32
# 29  Female  51.0             0              0         No Info  27.32
# 30    Male  67.0             0              0           never  27.32
# 31  Female  49.0             0              0         No Info  27.32
# 32  Female  56.0             0              0          former  27.32
# 33  Female  80.0             0              0         No Info  27.32
# 34  Female  80.0             0              0         No Info  27.32
# 35    Male  66.0             0              0         No Info  27.32
# 36    Male  80.0             0              0           never  27.32
# 37  Female  80.0             0              0           never  27.32
# 38    Male  56.0             0              0           never  27.32
# 39  Female  80.0             0              0         No Info  27.32
# 40  Female  75.0             0              0           never  27.32
# 41  Female  43.0             0              0           never  27.32
#
#     HbA1c_level  blood_glucose_level
# 0           5.8                  130
# 1           6.0                  140
# 2           6.5                  200
# 3           6.2                  159
# 4           6.6                  200
# 5           6.5                  145
# 6           5.7                  126
# 7           6.6                  140
# 8           6.2                  200
# 9           6.1                  126
# 10          6.1                  155
# 11          6.1                  155
# 12          5.7                  145
# 13          6.6                  145
# 14          5.8                  160
# 15          6.0                  145
# 16          6.0                  126
# 17          6.6                  155
# 18          5.8                  155
# 19          5.7                  145
# 20          5.7                  140
# 21          6.2                  160
# 22          6.6                  155
# 23          6.0                  145
# 24          6.0                  126
# 25          5.7                  145
# 26          6.0                  130
# 27          6.6                  126
# 28          6.1                  140
# 29          6.0                  159
# 30          6.2                  155
# 31          6.1                  160
# 32          6.5                  145
# 33          6.1                  155
# 34          6.6                  160
# 35          5.7                  130
# 36          6.1                  159
# 37          6.0                  200
# 38          6.2                  159
# 39          6.5                  145
# 40          6.2                  160
# 41          5.7                  140

# %%
K = int(input("Ingrese el valor de K: "))

folds = k_fold_cross_validation(X, y, K)

for i,(X_train,X_test,y_train, y_test) in enumerate(folds):
    print(f"Para el fold {i}")
    check_datasets(X_train,X_test)
# Out:
# Ingrese el valor de K:  18
# Para el fold 0
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0    Male  51.0             0              0           never  27.32
# 1  Female  80.0             0              0         No Info  27.32
# 2  Female  80.0             0              0         No Info  27.32
# 3  Female  44.0             0              0         No Info  27.32
# 4    Male  32.0             0              0         No Info  27.32
# 5  Female  28.0             0              0         No Info  27.32
# 6  Female  49.0             0              0         No Info  27.32
# 7  Female  68.0             0              0           never  27.32
# 8  Female  47.0             0              0           never  27.32
# 9    Male  55.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          5.7                  145
# 1          6.5                  159
# 2          6.5                  145
# 3          6.0                  145
# 4          6.5                  160
# 5          6.0                  140
# 6          6.1                  160
# 7          6.1                  126
# 8          5.7                  130
# 9          6.0                  145
# Para el fold 1
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0     Male  55.0             0              0           never  27.32
# 1   Female  57.0             0              0         No Info  27.32
# 2     Male  80.0             0              0           never  27.32
# 3   Female  37.0             0              0         No Info  27.32
# 4   Female  73.0             0              0          former  27.32
# 5   Female  47.0             0              0         No Info  27.32
# 6   Female  80.0             0              0         No Info  27.32
# 7   Female  80.0             1              0         No Info  27.32
# 8     Male  64.0             0              0         No Info  27.32
# 9   Female  80.0             0              0         No Info  27.32
# 10    Male  68.0             0              0          former  27.32
#
#     HbA1c_level  blood_glucose_level
# 0           6.6                  140
# 1           6.6                  126
# 2           6.1                  159
# 3           6.1                  155
# 4           6.6                  159
# 5           5.7                  126
# 6           5.8                  160
# 7           6.6                  155
# 8           6.6                  145
# 9           6.6                  160
# 10          6.0                  130
# Para el fold 2
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0   Female  75.0             0              0           never  27.32
# 1   Female  56.0             0              0          former  27.32
# 2     Male  32.0             0              0         No Info  27.32
# 3     Male  66.0             0              0         No Info  27.32
# 4   Female  80.0             0              0           never  27.32
# 5   Female  80.0             0              0         No Info  27.32
# 6   Female  51.0             0              0         No Info  27.32
# 7   Female  68.0             0              0         No Info  27.32
# 8     Male  64.0             0              0         No Info  27.32
# 9   Female  80.0             0              0           never  27.32
# 10    Male  62.0             0              0           never  27.32
#
#     HbA1c_level  blood_glucose_level
# 0           6.2                  160
# 1           6.5                  145
# 2           6.5                  160
# 3           5.7                  155
# 4           5.8                  155
# 5           6.5                  159
# 6           6.0                  159
# 7           6.5                  145
# 8           6.6                  155
# 9           5.7                  145
# 10          6.0                  145
# Para el fold 3
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0   Female  79.0             0              0         No Info  27.32
# 1     Male  66.0             0              0         No Info  27.32
# 2     Male  56.0             0              0           never  27.32
# 3     Male  53.0             0              0         No Info  27.32
# 4     Male  80.0             0              0         No Info  27.32
# 5   Female  58.0             0              0           never  27.32
# 6   Female   6.0             0              0         No Info  27.32
# 7   Female  43.0             0              0           never  27.32
# 8   Female  47.0             0              0           never  27.32
# 9   Female  45.0             0              0         No Info  27.32
# 10  Female  80.0             0              0           never  27.32
# 11  Female  48.0             0              0         current  27.32
# 12  Female  44.0             0              0         No Info  27.32
#
#     HbA1c_level  blood_glucose_level
# 0           6.1                  155
# 1           5.7                  155
# 2           6.2                  159
# 3           5.7                  140
# 4           6.2                  200
# 5           6.1                  140
# 6           6.6                  130
# 7           5.7                  140
# 8           5.7                  130
# 9           6.0                  126
# 10          5.8                  130
# 11          6.5                  200
# 12          6.0                  145
# Para el fold 4
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              0           never  27.32
# 1  Female  73.0             0              0          former  27.32
# 2    Male  73.0             0              0         No Info  27.32
# 3  Female  53.0             0              0         No Info  27.32
# 4  Female   6.0             0              0         No Info  27.32
# 5  Female  56.0             0              0           never  27.32
# 6    Male  67.0             0              0           never  27.32
# 7    Male  66.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.0                  200
# 1          6.6                  159
# 2          5.7                  145
# 3          6.2                  160
# 4          6.6                  130
# 5          6.2                  159
# 6          6.2                  155
# 7          5.7                  130
# Para el fold 5
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  28.0             0              0         No Info  27.32
# 1    Male  50.0             0              0         No Info  27.32
# 2  Female  80.0             0              0           never  27.32
# 3    Male  69.0             0              0     not current  27.32
# 4  Female  80.0             0              0         No Info  27.32
# 5  Female  80.0             0              0         No Info  27.32
# 6  Female  60.0             0              0         No Info  27.32
# 7  Female  56.0             0              0         No Info  27.32
# 8    Male  74.0             0              0         No Info  27.32
# 9  Female  80.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.0                  140
# 1          5.7                  200
# 2          5.8                  130
# 3          6.0                  155
# 4          6.1                  155
# 5          6.0                  126
# 6          6.6                  200
# 7          6.2                  126
# 8          5.8                  159
# 9          6.5                  160
# Para el fold 6
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  47.0             0              0         No Info  27.32
# 1  Female  59.0             0              0         No Info  27.32
# 2  Female  48.0             0              0         current  27.32
# 3  Female  56.0             0              0           never  27.32
# 4  Female  80.0             0              0         No Info  27.32
# 5  Female  68.0             0              0         No Info  27.32
# 6  Female  40.0             0              0         No Info  27.32
# 7  Female  60.0             0              0         No Info  27.32
# 8  Female  79.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          5.7                  126
# 1          6.1                  160
# 2          6.5                  200
# 3          6.2                  159
# 4          5.8                  155
# 5          6.5                  145
# 6          5.8                  126
# 7          6.6                  200
# 8          6.6                  160
# Para el fold 7
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              0         No Info  27.32
# 1  Female  37.0             0              0         No Info  27.32
# 2  Female  68.0             0              0           never  27.32
# 3  Female  61.0             0              0           never  27.32
# 4  Female  56.0             0              0         No Info  27.32
# 5    Male  80.0             0              0         No Info  27.32
# 6    Male  55.0             0              0           never  27.32
# 7    Male  44.0             0              0           never  27.32
# 8  Female  79.0             0              0         No Info  27.32
# 9  Female  80.0             1              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          5.8                  155
# 1          6.1                  155
# 2          6.1                  126
# 3          5.8                  130
# 4          6.2                  126
# 5          6.2                  200
# 6          6.6                  140
# 7          6.2                  126
# 8          6.1                  155
# 9          5.8                  155
# Para el fold 8
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              0         No Info  27.32
# 1  Female  61.0             0              0           never  27.32
# 2  Female  40.0             0              0         No Info  27.32
# 3    Male  64.0             0              0         No Info  27.32
# 4  Female  61.0             0              0     not current  27.32
# 5    Male  42.0             0              0           never  27.32
# 6  Female  51.0             0              0         No Info  27.32
# 7  Female  74.0             0              0         No Info  27.32
# 8    Male  51.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          5.8                  160
# 1          6.0                  200
# 2          5.8                  126
# 3          6.6                  145
# 4          5.7                  200
# 5          6.1                  140
# 6          5.7                  126
# 7          6.2                  145
# 8          5.7                  145
# Para el fold 9
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              0           never  27.32
# 1  Female  61.0             0              0           never  27.32
# 2  Female  80.0             0              0           never  27.32
# 3  Female  80.0             0              0         No Info  27.32
# 4    Male  61.0             0              0         No Info  27.32
# 5  Female  80.0             1              0         No Info  27.32
# 6    Male  40.0             0              0           never  27.32
# 7  Female  61.0             0              0           never  27.32
# 8    Male  62.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.2                  140
# 1          5.8                  130
# 2          6.5                  160
# 3          6.0                  126
# 4          5.8                  126
# 5          6.6                  155
# 6          6.2                  160
# 7          6.0                  200
# 8          6.0                  145
# Para el fold 10
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              0           never  27.32
# 1  Female  53.0             0              0         No Info  27.32
# 2  Female  66.0             0              0         No Info  27.32
# 3  Female  80.0             1              0         No Info  27.32
# 4    Male  73.0             0              0         No Info  27.32
# 5  Female  79.0             0              0         No Info  27.32
# 6    Male  53.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          5.8                  155
# 1          6.2                  160
# 2          6.2                  145
# 3          5.8                  155
# 4          5.7                  145
# 5          6.6                  160
# 6          5.7                  140
# Para el fold 11
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0    Male  64.0             0              0         No Info  27.32
# 1  Female  45.0             0              0         No Info  27.32
# 2  Female  80.0             0              0           never  27.32
# 3  Female  73.0             0              0         No Info  27.32
# 4    Male  55.0             0              0         No Info  27.32
# 5  Female  80.0             0              0           never  27.32
# 6    Male  68.0             0              0          former  27.32
# 7  Female  56.0             0              0           never  27.32
# 8    Male  55.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.6                  155
# 1          6.0                  126
# 2          6.6                  160
# 3          5.8                  160
# 4          6.0                  145
# 5          5.7                  145
# 6          6.0                  130
# 7          6.2                  160
# 8          6.5                  145
# Para el fold 12
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0    Male  40.0             0              0           never  27.32
# 1    Male  56.0             0              0         No Info  27.32
# 2    Male  59.0             0              0     not current  27.32
# 3  Female  80.0             0              0           never  27.32
# 4  Female  59.0             0              0         No Info  27.32
# 5    Male  44.0             0              0           never  27.32
# 6    Male  80.0             0              0         current  27.32
# 7    Male  80.0             0              0         No Info  27.32
# 8  Female  66.0             0              0         No Info  27.32
# 9    Male  61.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.2                  160
# 1          6.1                  200
# 2          5.7                  160
# 3          6.2                  159
# 4          6.1                  160
# 5          6.2                  126
# 6          6.2                  126
# 7          5.7                  140
# 8          6.2                  145
# 9          5.8                  126
# Para el fold 13
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0     Male  52.0             0              0          former  27.32
# 1   Female  51.0             0              0         No Info  27.32
# 2     Male  67.0             0              0           never  27.32
# 3   Female  80.0             1              0           never  27.32
# 4   Female  57.0             0              0         No Info  27.32
# 5     Male  51.0             0              0         No Info  27.32
# 6   Female  58.0             0              0           never  27.32
# 7     Male  42.0             0              0           never  27.32
# 8   Female  47.0             0              0         No Info  27.32
# 9     Male  80.0             0              0         current  27.32
# 10  Female  56.0             0              0           never  27.32
# 11  Female  61.0             0              0     not current  27.32
# 12  Female  74.0             0              0         No Info  27.32
#
#     HbA1c_level  blood_glucose_level
# 0           6.1                  140
# 1           6.0                  159
# 2           6.2                  155
# 3           5.8                  155
# 4           6.6                  126
# 5           6.0                  126
# 6           6.1                  140
# 7           6.1                  140
# 8           6.0                  145
# 9           6.2                  126
# 10          6.2                  160
# 11          5.7                  200
# 12          6.2                  145
# Para el fold 14
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  49.0             0              0         No Info  27.32
# 1  Female  80.0             1              0           never  27.32
# 2    Male  74.0             0              0         No Info  27.32
# 3  Female  68.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.1                  160
# 1          5.8                  155
# 2          5.8                  159
# 3          6.2                  145
# Para el fold 15
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0    Male  56.0             0              0         No Info  27.32
# 1  Female  80.0             0              0         No Info  27.32
# 2    Male  50.0             0              0         No Info  27.32
# 3    Male  59.0             0              0     not current  27.32
# 4  Female  56.0             0              0          former  27.32
# 5  Female  47.0             0              0         No Info  27.32
# 6  Female  80.0             0              0         No Info  27.32
# 7  Female  73.0             0              0         No Info  27.32
# 8  Female  80.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.1                  200
# 1          6.6                  160
# 2          5.7                  200
# 3          5.7                  160
# 4          6.5                  145
# 5          6.0                  145
# 6          6.1                  155
# 7          5.8                  160
# 8          6.2                  140
# Para el fold 16
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0    Male  80.0             0              0         No Info  27.32
# 1    Male  69.0             0              0     not current  27.32
# 2    Male  66.0             0              0         No Info  27.32
# 3    Male  80.0             0              0           never  27.32
# 4    Male  52.0             0              0          former  27.32
# 5  Female  51.0             0              0         No Info  27.32
# 6  Female  68.0             0              0         No Info  27.32
# 7    Male  80.0             0              0         No Info  27.32
# 8  Female  80.0             0              0           never  27.32
# 9    Male  55.0             0              0         No Info  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.5                  155
# 1          6.0                  155
# 2          5.7                  130
# 3          6.1                  159
# 4          6.1                  140
# 5          5.7                  126
# 6          6.2                  145
# 7          5.7                  140
# 8          6.0                  200
# 9          6.5                  145
# Para el fold 17
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0    Male  51.0             0              0         No Info  27.32
# 1  Female  80.0             0              0           never  27.32
# 2  Female  75.0             0              0           never  27.32
# 3    Male  80.0             0              0         No Info  27.32
# 4  Female  80.0             0              0         No Info  27.32
# 5    Male  56.0             0              0           never  27.32
# 6  Female  43.0             0              0           never  27.32
# 7  Female  80.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level
# 0          6.0                  126
# 1          6.2                  159
# 2          6.2                  160
# 3          6.5                  155
# 4          6.5                  145
# 5          6.2                  159
# 6          5.7                  140
# 7          6.6                  160

# %%
# Data credit card
X = creditCard[['Debt','Married','BankCustomer','Industry','Ethnicity','YearsEmployed','PriorDefault','Employed','CreditScore']]
y = creditCard['Approved']
r = float(input("Ingrese el valor de r: "))
X_train, X_test, y_train, y_test = holdout_validation(X, y, r)
check_datasets(X_train,X_test)
# Out:
# Ingrese el valor de r:  0.2
# Los conjuntos de entrenamiento y prueba son disjuntos.

# %%
K = int(input("Ingrese el valor de K: "))
folds = k_fold_cross_validation(X, y, K)

for i,(X_train,X_test,y_train, y_test) in enumerate(folds):
    print(f"Para el fold {i}")
    check_datasets(X_train,X_test)
# Out:
# Ingrese el valor de K:  6
# Para el fold 0
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el fold 1
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el fold 2
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    Debt  Married  BankCustomer Industry Ethnicity  YearsEmployed  \
# 0   0.0        1             1   Energy     White            0.0
# 1   0.0        1             1   Energy     White            0.0
# 2   0.0        1             1   Energy     White            0.0
# 3   0.0        1             1   Energy     White            0.0
# 4   0.0        1             1   Energy     White            0.0
#
#    PriorDefault  Employed  CreditScore
# 0             0         0            0
# 1             0         0            0
# 2             0         0            0
# 3             0         0            0
# 4             0         0            0
# Para el fold 3
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    Debt  Married  BankCustomer Industry Ethnicity  YearsEmployed  \
# 0   0.0        1             1   Energy     White            0.0
# 1   0.0        1             1   Energy     White            0.0
# 2   0.0        1             1   Energy     White            0.0
# 3   0.0        1             1   Energy     White            0.0
# 4   0.0        1             1   Energy     White            0.0
#
#    PriorDefault  Employed  CreditScore
# 0             0         0            0
# 1             0         0            0
# 2             0         0            0
# 3             0         0            0
# 4             0         0            0
# Para el fold 4
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    Debt  Married  BankCustomer Industry Ethnicity  YearsEmployed  \
# 0   0.0        1             1   Energy     White            0.0
# 1   0.0        1             1   Energy     White            0.0
# 2   0.0        1             1   Energy     White            0.0
# 3   0.0        1             1   Energy     White            0.0
# 4   0.0        1             1   Energy     White            0.0
#
#    PriorDefault  Employed  CreditScore
# 0             0         0            0
# 1             0         0            0
# 2             0         0            0
# 3             0         0            0
# 4             0         0            0
# Para el fold 5
# Los conjuntos de entrenamiento y prueba NO son disjuntos.
#    Debt  Married  BankCustomer Industry Ethnicity  YearsEmployed  \
# 0   0.0        1             1   Energy     White            0.0
# 1   0.0        1             1   Energy     White            0.0
# 2   0.0        1             1   Energy     White            0.0
# 3   0.0        1             1   Energy     White            0.0
# 4   0.0        1             1   Energy     White            0.0
# 5   0.0        1             1   Energy     White            0.0
# 6   0.0        1             1   Energy     White            0.0
# 7   0.0        1             1   Energy     White            0.0
# 8   0.0        1             1   Energy     White            0.0
#
#    PriorDefault  Employed  CreditScore
# 0             0         0            0
# 1             0         0            0
# 2             0         0            0
# 3             0         0            0
# 4             0         0            0
# 5             0         0            0
# 6             0         0            0
# 7             0         0            0
# 8             0         0            0

# %%
leaveVali = leave_one_out_validation(X, y)

for i,(X_train,X_test,y_train, y_test) in enumerate(leaveVali):
    print(f"Para el conjunto {i}")
    check_datasets(X_train,X_test)
# Out:
# Para el conjunto 0
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 1
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 2
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 3
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 4
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 5
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 6
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 7
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 8
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 9
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 10
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 11
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 12
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 13
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 14
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 15
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 16
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 17
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 18
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 19
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 20
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 21
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 22
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 23
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 24
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 25
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 26
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 27
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 28
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 29
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 30
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 31
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 32
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 33
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 34
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 35
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 36
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 37
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto 38
# Los conjuntos de entrenamiento y prueba son disjuntos.
# Para el conjunto